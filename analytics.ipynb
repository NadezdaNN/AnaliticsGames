# %% [markdown]
# ### Анализ данных, полученных в ходе опроса пользователей интернета, для выявления их отношения к онлайн-играм

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('NewForm.csv')
display(data.head(10))
print('Размерность:', data.shape)
# Out:
#                 Отметка времени  Ваш пол Сколько вам лет?  \
# 0  2024/08/01 10:47:01 AM GMT+3  Женский        25-45 лет
# 1  2024/08/01 10:47:33 AM GMT+3  Женский        18-25 лет
# 2  2024/08/01 10:48:11 AM GMT+3  Женский        25-45 лет
# 3  2024/08/01 10:48:37 AM GMT+3  Женский        25-45 лет
# 4  2024/08/01 10:49:13 AM GMT+3  Женский        25-45 лет
# 5  2024/08/01 10:50:47 AM GMT+3  Мужской        18-25 лет
# 6  2024/08/01 10:54:18 AM GMT+3  Женский        25-45 лет
# 7  2024/08/01 11:02:19 AM GMT+3  Женский        18-25 лет
# 8  2024/08/01 11:04:36 AM GMT+3  Мужской        25-45 лет
# 9  2024/08/01 11:06:16 AM GMT+3  Мужской        25-45 лет
#
#   Занимаетесь ли вы благотворительной деятельностью?  \
# 0       Да, я доначу в благотворительные организации
# 1                                                Нет
# 2                                                Нет
# 3                                                Нет
# 4       Да, я доначу в благотворительные организации
# ...

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_axes((1, 1, 1, 1))
count = data['Ваш пол'].value_counts()
pie = ax.pie(
    count,
    labels=['Женщины', 'Мужчины'],
    autopct='%1.1f%%',
    startangle=90
)
title = ax.set_title('Соотношение респондентов по гендерному признаку', fontsize=16)

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_axes((1, 1, 1, 1))
count = data['Сколько вам лет?'].value_counts() #.sort_values(ascending=False)
pie = ax.pie(
    count,
    labels=count.index,
    autopct='%1.1f%%',
    startangle=90
)
title = ax.set_title('Соотношение респондентов по возрасту', fontsize=16)
plt.show(pie)

# %%
mask = data['Ваш пол'] == 'Женский'
mask2 = data['Ваш пол'] == 'Мужской'
data_tmp = data[mask]
data_tmp2 = data[mask2]

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))

count = data_tmp['Сколько вам лет?'].value_counts() 
count2 = data_tmp2['Сколько вам лет?'].value_counts()

axes[0].pie(
    count,
    labels=count.index,
    autopct='%1.1f%%',
    startangle=90
)
axes[0].set_title('Соотношение респондентов по возрасту\n среди женщин', fontsize=12);
axes[1].pie(
    count2,
    labels=count2.index,
    autopct='%1.1f%%',
    startangle=90
)

axes[1].set_title('Соотношение респондентов по возрасту\n среди мужчин', fontsize=12);
plt.show(pie)

# %% [markdown]
# ### Вывод.
#
# Видим, что как среди женщин, так и среди мужчин преобладают люди возрастов 25-45 лет (примерно 63% опрошенных), и 18-25 лет (примерно 28% опрошенных).

# %%
display(data['Занимаетесь ли вы благотворительной деятельностью?'].value_counts())

fig = plt.figure(figsize=(10, 5))
ax = fig.add_axes((1, 1, 1, 1))
data_tmp = data 

data_tmp['Занимаетесь ли вы благотворительной деятельностью?'] = \
    data_tmp['Занимаетесь ли вы благотворительной деятельностью?'].apply(lambda x: 'Да, я доначу\nв благотворительные\n организации' if x == 'Да, я доначу в благотворительные организации' else x)
count = data_tmp['Занимаетесь ли вы благотворительной деятельностью?'].value_counts().sort_values()
pie = ax.pie(
    count,
    labels=count.index,
    autopct='%1.1f%%',
    startangle=90,
    explode = [0, 0, 0.01]
)
title = ax.set_title('Занимаетесь ли вы благотворительной деятельностью?', fontsize=16)
plt.show(pie)
# Out:
# Занимаетесь ли вы благотворительной деятельностью?
# Нет                                             55
# Да, я доначу в благотворительные организации    34
# Да, я волонтер                                   8
# Name: count, dtype: int64

# %%
mask = data['Ваш пол'] == 'Женский'
mask2 = data['Ваш пол'] == 'Мужской'
data_tmp = data[mask]
data_tmp2 = data[mask2]

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))

count = data_tmp['Занимаетесь ли вы благотворительной деятельностью?'].value_counts() 
count2 = data_tmp2['Занимаетесь ли вы благотворительной деятельностью?'].value_counts()

axes[0].pie(
    count,
    labels=count.index,
    autopct='%1.1f%%',
    startangle=90,
    explode = [0, 0, 0.05]
)
axes[0].set_title('Занимаетесь ли вы благотворительной деятельностью?\n(Женщины)', fontsize=12);
axes[1].pie(
    count2,
    labels=count2.index,
    autopct='%1.1f%%',
    startangle=90,
    explode = [0, 0, 0.05]
)

axes[1].set_title('Занимаетесь ли вы благотворительной деятельностью?\n(Мужчины)', fontsize=12);
plt.show(pie)

# %% [markdown]
# ### Вывод.
#
# Видим, что в процентном соотношении, доля волонтеров среди женщин и среди мужчин примерно одинакова. При этом, женщины чаще донатят в благотворительные организации, чем мужчины (41.1% против 16.7%).

# %%
data['Играете ли вы в онлайн-игры?'].value_counts()
# Out:
# Играете ли вы в онлайн-игры?
# Да, на телефоне                                       24
# Да, на компьютере;Да, на телефоне                     21
# Да, на компьютере                                     19
# Нет, не играю                                         18
# Да, на компьютере;Да, на телефоне;Да, на приставке     7
# Да, на компьютере;Да, на приставке                     2
# Да, на приставке                                       2
# Да, на телефоне;Да, на приставке                       2
# Да, на компьютере;Нет, не играю                        1
# Да, на телефоне;Нет, не играю                          1
# Name: count, dtype: int64

# %% [markdown]
# Ответы всего двух респондентов на вопрос: 'Играете ли вы в онлайн-игры?' можно считать неоднозначными: 'Да, на компьютере;Нет, не играю' и 'Да, на телефоне;Нет, не играю'. Будем считать их статистически незначимыми.

# %%
data_tmp = []
for k,i in enumerate(data['Играете ли вы в онлайн-игры?']):      
    if ';' in i:        
        i_tmp = i.split(';')
        for j in i_tmp:
            data_tmp.append(j)                 
    else:
        data_tmp.append(i)   
        
data_tmp = pd.Series(data_tmp)

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_axes((1, 1, 1, 1))
count = data_tmp.value_counts().sort_values() 
display(count)
pie = ax.pie(
    count,
    labels=count.index,
    autopct='%1.1f%%',
    startangle=90, 
    explode = [0, 0, 0.01, 0]
)
title = ax.set_title('Играете ли вы в онлайн-игры?', fontsize=16)
plt.show(pie)
# Out:
# Да, на приставке     13
# Нет, не играю        20
# Да, на компьютере    50
# Да, на телефоне      55
# Name: count, dtype: int64

# %%
mask = data['Ваш пол'] == 'Женский'
mask2 = data['Ваш пол'] == 'Мужской'
data_f = data[mask]
data_m = data[mask2]
data_tmp_f = []
for k,i in enumerate(data_f['Играете ли вы в онлайн-игры?']):      
    if ';' in i:        
        i_tmp = i.split(';')
        for j in i_tmp:
            data_tmp_f.append(j)                 
    else:
        data_tmp_f.append(i)   
data_tmp_f = pd.Series(data_tmp_f)        
data_tmp_m = []
for k,i in enumerate(data_m['Играете ли вы в онлайн-игры?']):      
    if ';' in i:        
        i_tmp = i.split(';')
        for j in i_tmp:
            data_tmp_m.append(j)                 
    else:
        data_tmp_m.append(i)   
data_tmp_m = pd.Series(data_tmp_m)
#display(data_tmp_f)
#display(data_tmp_m)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))

count = data_tmp_f.value_counts() 
count2 = data_tmp_m.value_counts()
display(count)
axes[0].pie(
    count,
    labels=count.index,
    autopct='%1.1f%%',
    startangle=90,
    explode = [0, 0.01, 0, 0]
)
axes[0].set_title('Играете ли вы в онлайн-игры?\n(Женщины)', fontsize=12);

axes[1].pie(
    count2,
    labels=count2.index,
    autopct='%1.1f%%',
    startangle=90,
    explode = [0.01, 0, 0, 0]
)
axes[1].set_title('Играете ли вы в онлайн-игры?\n(Мужчины)', fontsize=12);
plt.show(pie)
# Out:
# Да, на телефоне      48
# Да, на компьютере    32
# Нет, не играю        15
# Да, на приставке     11
# Name: count, dtype: int64

# %% [markdown]
# ### Вывод
#
# Видим, что процент играющих онлайн на компьютере выше среди мужчины (56.2%), чем среди женщины (30.2%). При этом, 45.3% женщин предпочитает играть на телефоне, в то время как среди мужчин этот показатель всего 21.9%

# %%
data['В игры каких жанров на ПК вы играете чаще всего, можно выбрать несколько вариантов'].value_counts()
# Out:
# В игры каких жанров на ПК вы играете чаще всего, можно выбрать несколько вариантов
# головоломки                                                                                                    11
# ролевые RPG                                                                                                     5
# головоломки;игры с менеджментом фермы, отеля, города                                                            4
# файтинги, стрелялки;ролевые RPG                                                                                 3
# игры с менеджментом фермы, отеля, города                                                                        3
# головоломки;файтинги, стрелялки                                                                                 3
# Не играю                                                                                                        3
# ...

# %%
# Исключаем респондентов, которые ответили, что не играют в онлайн-игры
mask = data['Играете ли вы в онлайн-игры?'] != 'Нет, не играю'
data_game = data[mask]
#display(data_game['Играете ли вы в онлайн-игры?'].value_counts())

# %%
data_tmp = []
data_game['В игры каких жанров на ПК вы играете чаще всего, можно выбрать несколько вариантов'] = \
    data_game['В игры каких жанров на ПК вы играете чаще всего, можно выбрать несколько вариантов'].fillna(str(0))
for i in data_game['В игры каких жанров на ПК вы играете чаще всего, можно выбрать несколько вариантов']:    
    i_tmp = i    
    if ';' in i:        
        i_tmp = i.split(';')
        for j in i_tmp:
            data_tmp.append(j)
    else:
        data_tmp.append(i_tmp)
    
data_game = pd.Series(data_tmp)
display(data_game.value_counts())
# Out:
# головоломки                                                                                41
# ролевые RPG                                                                                35
# файтинги, стрелялки                                                                        21
# игры с менеджментом фермы, отеля, города                                                   21
# стратегии                                                                                  17
# MMORPG                                                                                     16
# гонки                                                                                      14
# поиск предметов                                                                            10
# рогалики                                                                                    1
# Три в ряд в разных вариациях                                                                1
# ...

# %%
data_game = data_game.apply(lambda x: 'другое' if (x!='головоломки' and x!='ролевые RPG' and x!='файтинги, стрелялки' and \
                                                        x!='игры с менеджментом фермы, отеля, города' and \
                                                            x!='стратегии' and x!='MMORPG' and x!='гонки' and \
                                                                x!='поиск предметов') else x)
data_game = data_game.apply(lambda x: 'игры с менеджментом\n фермы, отеля, города' if x == 'игры с менеджментом фермы, отеля, города' else x)
data_game = data_game.apply(lambda x: 'файтинги,\n стрелялки' if x == 'файтинги, стрелялки' else x)
data_game = data_game.apply(lambda x: 'поиск\n предметов' if x == 'поиск предметов' else x)

fig = plt.figure(figsize=(10, 5))
ax = fig.add_axes((1, 1, 1, 1))
 
count = data_game.value_counts()

pie = ax.pie(
    count,
    labels=count.index,
    autopct='%1.1f%%',
    startangle=90,
    explode = [0, 0, 0, 0.02, 0, 0, 0, 0, 0]
)
title = ax.set_title('В игры каких жанров на ПК вы играете чаще всего?', fontsize=16)
plt.show(pie)

# %%
# Сколько вы потратили денег на внутриигровые покупки за последние полгода?
data['Сколько вы потратили денег на внутриигровые покупки за последние полгода?'] = \
    data['Сколько вы потратили денег на внутриигровые покупки за последние полгода?'].fillna(str('менее 100 руб.'))

data['Сколько вы потратили денег на внутриигровые покупки за последние полгода?'] = \
    data['Сколько вы потратили денег на внутриигровые покупки за последние полгода?'].apply(lambda x: 'более 5000 руб.' if x == 'более 5000руб.' else x)
display(data['Сколько вы потратили денег на внутриигровые покупки за последние полгода?'].value_counts())

mask = data['Играете ли вы в онлайн-игры?'] != 'Нет, не играю'
data_copy = data[mask]
display(data_copy['Сколько вы потратили денег на внутриигровые покупки за последние полгода?'].value_counts())
# Out:
# Сколько вы потратили денег на внутриигровые покупки за последние полгода?
# менее 100 руб.        69
# от 100 до 500 руб.    11
# 501-1000 руб.          6
# 2001-5000 руб.         5
# 1001-2000 руб.         4
# более 5000 руб.        2
# Name: count, dtype: int64
# Сколько вы потратили денег на внутриигровые покупки за последние полгода?
# менее 100 руб.        51
# от 100 до 500 руб.    11
# 501-1000 руб.          6
# 2001-5000 руб.         5
# 1001-2000 руб.         4
# более 5000 руб.        2
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_axes((1, 1, 1, 1))
count = data_copy['Сколько вы потратили денег на внутриигровые покупки за последние полгода?'].value_counts().sort_values()
pie = ax.pie(
    count,
    labels=count.index,
    autopct='%1.1f%%',
    startangle=90, 
    explode = [0, 0, 0, 0, 0, 0.01]
)
title = ax.set_title('Сколько вы потратили денег на внутриигровые\n покупки за последние полгода?', fontsize=16)
plt.show(pie)

# %%
# Какую покупку вы вероятнее всего совершите в игре?
data['Какую покупку вы вероятнее всего совершите в игре?'] = data['Какую покупку вы вероятнее всего совершите в игре?'].fillna('Никакую')
mask = data['Играете ли вы в онлайн-игры?'] != 'Нет, не играю'
data_copy = data[mask]
data_copy['Какую покупку вы вероятнее всего совершите в игре?'].value_counts()
# Out:
# Какую покупку вы вероятнее всего совершите в игре?
# уникальные скины, персонажи       28
# возможность играть без рекламы    23
# дополнительные жизни, энергии     13
# игровые бустеры, подсказки        11
# Никакую                            4
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_axes((1, 1, 1, 1))
count = data_copy['Какую покупку вы вероятнее всего совершите в игре?'].value_counts().sort_values()
pie = ax.pie(
    count,
    labels=count.index,
    autopct='%1.1f%%',
    startangle=90,
    explode = [0, 0, 0, 0, 0.01]
)
title = ax.set_title('Какую покупку вы вероятнее всего совершите в игре?', fontsize=16)
plt.show(pie)

# %%
# Какую покупку вы вероятнее всего совершите в игре? (Для ответивших, что совершили покупки менее чем на 100 руб.)

mask = data['Сколько вы потратили денег на внутриигровые покупки за последние полгода?'] == 'менее 100 руб.'
data_copy = data[mask]

fig = plt.figure(figsize=(10, 5))
ax = fig.add_axes((1, 1, 1, 1))
count = data_copy['Какую покупку вы вероятнее всего совершите в игре?'].value_counts().sort_values()
pie = ax.pie(
    count,
    labels=count.index,
    autopct='%1.1f%%',
    startangle=90,
    explode = [0, 0, 0, 0, 0.01]
)
title = ax.set_title('Какую покупку вы вероятнее всего совершите в игре?\n (ответы респондентов, совершивших покупки менее чем на 100 руб.)', fontsize=12)
plt.show(pie)

# %%
# Что на ваш взгляд самое важное в игре?
data['Что на ваш взгляд самое важное в игре?'].value_counts()
# Out:
# Что на ваш взгляд самое важное в игре?
# интересный сюжет и проработанные персонажи                                                                                                                                                                                                   10
# интересный сюжет и проработанные персонажи;возможность бесплатного прогресса;игра не требует пристального внимания, можно играть в любое время                                                                                                9
# игра не требует пристального внимания, можно играть в любое время                                                                                                                                                                             8
# ...

# %%
data['Что на ваш взгляд самое важное в игре?'] = data['Что на ваш взгляд самое важное в игре?'].fillna(str('другое'))
data_tmp = []
for i in data['Что на ваш взгляд самое важное в игре?']:    
    i_tmp = i    
    if ';' in i:        
        i_tmp = i.split(';')
        for j in i_tmp:
            data_tmp.append(j)
    else:
        data_tmp.append(i_tmp)    
data_tmp = pd.Series(data_tmp)
display(data_tmp.value_counts())
# Out:
# интересный сюжет и проработанные персонажи                           65
# игра не требует пристального внимания, можно играть в любое время    48
# возможность бесплатного прогресса                                    43
# расслабляющая атмосфера игры                                         39
# динамика в игре, необходимость принять быстрое решение               23
# возможность внутриигрового общениия                                  15
# другое                                                                5
# возможность купить бустеры, ускорители для игры                       4
# Name: count, dtype: int64

# %%
data_tmp = data_tmp.apply(lambda x: 'игра не требует пристального внимания,\n можно играть в любое время' \
                          if x == 'игра не требует пристального внимания, можно играть в любое время' else x)
data_tmp = data_tmp.apply(lambda x: 'динамика в игре,\n необходимость принять\n быстрое решение' \
                          if x == 'динамика в игре, необходимость принять быстрое решение' else x)
data_tmp = data_tmp.apply(lambda x: 'интересный сюжет\n и проработанные персонажи' \
                          if x == 'интересный сюжет и проработанные персонажи' else x)
data_tmp = data_tmp.apply(lambda x: 'другое' \
                          if x == 'возможность купить бустеры, ускорители для игры' else x)
data_tmp = data_tmp.apply(lambda x: 'расслабляющая\n атмосфера игры' \
                          if x == 'расслабляющая атмосфера игры' else x)
data_tmp = data_tmp.apply(lambda x: 'возможность\n внутриигрового\n общениия' \
                          if x == 'возможность внутриигрового общениия' else x)
data_tmp = data_tmp.apply(lambda x: 'возможность\n бесплатного прогресса' \
                          if x == 'возможность бесплатного прогресса' else x)

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_axes((1, 1, 1, 1))
deaths_count = data_tmp.value_counts().sort_values() 
pie = ax.pie(
    deaths_count,
    labels=deaths_count.index,
    autopct='%1.1f%%',
    startangle=90,
    explode = [0, 0, 0, 0, 0, 0, 0.01]    
)
title = ax.set_title('Что на ваш взгляд самое важное в игре?', fontsize=16)
plt.show(pie)

# %%
data['Как вы узнаете о новых играх?'].value_counts()
# Out:
# Как вы узнаете о новых играх?
# Рекомендации знакомых                                                                                                            19
# Обзоры и стримы блогеров                                                                                                         12
# Контекстная реклама в браузере, сторонних приложениях;Рекомендации знакомых                                                      11
# Контекстная реклама в браузере, сторонних приложениях                                                                            10
# Рекомендации знакомых;Обзоры и стримы блогеров                                                                                    9
# рейтинг игры в топах игр                                                                                                          6
# Обзоры и стримы блогеров;рейтинг игры в топах игр                                                                                 6
# ...

# %%
# В игры каких жанров на ПК вы играете чаще всего, можно выбрать несколько вариантов
data['Как вы узнаете о новых играх?'] = data['Как вы узнаете о новых играх?'].fillna(str('Другое'))
data_tmp = []
for i in data['Как вы узнаете о новых играх?']:    
    i_tmp = i    
    if ';' in i:        
        i_tmp = i.split(';')
        for j in i_tmp:
            data_tmp.append(j)
    else:
        data_tmp.append(i_tmp)    
data_tmp = pd.Series(data_tmp)
display(data_tmp.value_counts())
# Out:
# Рекомендации знакомых                                    51
# Обзоры и стримы блогеров                                 35
# Контекстная реклама в браузере, сторонних приложениях    26
# рейтинг игры в топах игр                                 24
# Другое                                                   10
# Name: count, dtype: int64

# %%
data_tmp = data_tmp.apply(lambda x: 'Контекстная реклама в браузере,\n сторонних приложениях' if x == 'Контекстная реклама в браузере, сторонних приложениях' else x)
data_tmp = data_tmp.apply(lambda x: 'Рейтинг игры в топах игр' if x == 'рейтинг игры в топах игр' else x)
data_tmp = data_tmp.apply(lambda x: 'Рекомендации\n знакомых' if x == 'Рекомендации знакомых' else x)

fig = plt.figure(figsize=(10, 5))
ax = fig.add_axes((1, 1, 1, 1))
deaths_count = data_tmp.value_counts()#.sort_values().head(7) 
pie = ax.pie(
    deaths_count,
    labels=deaths_count.index,
    autopct='%1.1f%%',
    startangle=90,
    explode = [0.01, 0, 0, 0, 0] 
)
title = ax.set_title('Как вы узнаете о новых играх?', fontsize=16)
plt.show(pie)

# %% [markdown]
# ## Выводы.
#
# * В проведенном опросе пользователей интернета приняли участие как мужчины, так и женщины (25% и 75% соответственно). См. график 1.png
# * Возраст респондентов составляет преимущественно 25-45 лет (62%) и 18-25 лет (30%). См. график 2.png
# * Более половины опрошенных не занимаются благотворительной деятельностью (57%), но при этом 35% - донатят благотворительным организациям, а 8% - являются волонтерами. См. график 4.png
# * Возможно, стоит обратить внимание, что среди женщин и мужчин количество волонтеров в процентном соотношении одинаково (по 8%), но женщины чаще донатят благотворительным организациям (41% против 17%). См. график 5.png
# * Среди респондентов примерно одинаковый процент играющих в онлайн-игры на компьютере и на телефоне (36% и 40% соответственно). См. график 6.png.
# При этом, играть на компьютере предпочитают только 35% женщин, а среди мужчин этот показатель достигает 56%. См. график 7.png
# * Респонденты чаще всего играют в игры таких жанров:
# 1. головоломки (22%),
# 2. ролевые RPG (18.5%),
# 3. игры с менеджментом отеля, города, фермы (11%),
# 4. файтинги, стрелялки (11%),
# 5. стратегии (9%)
# Т.о. игры жанра тайкун (стратегия, фокусирующаяся на менеджменте предприятия) входит в 5ку самых популярных направлений. См. график 8.png
# * 65% опрошенных не совершают покупки в онлайн-играх или потратили на них менее 100 руб. за последние полгода, 14% - совершили покупки на сумму 100-500 руб., 7.6% - на сумму 501-1000 руб. и т.д. См. график 9.png
# * Чаще всего респонденты покупают в играх:
# 1. уникальные скины и персонажей (35.4%),
# 2. возможность играть без рекламы (29%),
# 3. дополнительные жизни и энергии (16.5%). См. график 10.png
# Отметим, что среди тех, кто не совершал покупки или потратил на них менее 100 рублей, вероятнее всего совершат покупку "возможности играть без рекламы" (41%), а так же покупку "уникальные скины и персонажи" - 25%. См. график 10_2.png
# * Наиболее важным в игре респонденты считают интересный сюжет и проработанных персонажей (27%), а так же возможность играть в любое время/игра не требует пристального внимания - 20%. См. график 11.png
# * Наибольшая часть опрошенных узнает о новых играх из рекомендаций знакомых (35%), а так же, из обзоров блогеров (24%), и контекстной рекламы в браузере и сторонних приложениях (20%). См. график 12.png
