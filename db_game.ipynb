# %%
import pandas as pd

# %% [markdown]
# Таблица1: "Users" - таблица для сохранения состояния игры для каждого пользователя. Во многих столбцах используется тип данных JSON. Она содержит:
# * настройки пользователя,
# * ресурсы - валюта обычная, спецвалюта, ресурсы для построения/добавления новых кабинетов
# * локации, которые задействованы у конкретного пользователя (ресепшен, палата, кабинет и т.д.),
#   пациентов, которые находятся в конкретной локации, их состояние и настроение
#
# Такие параметры как валюта, состояние и настроение пациента/родителя будут меняться по ходу игры. Так же будут добавляться локации и меняться их уровень обустройства.

# %%
data = {
    'email': ['user1@yandex.ru', 'user2@mail.ru'], 
    'password': ["qwerty", 123],
    'settings': [{"volue": 0, "notifications": 1, "language": "ru"}, 
                 {"volue": 1, "notifications": 0, "language": "ru"}, ],
    'resources': [{'currency_standard': 500, 'currency_special': 0, 'building': 50},
                  {'currency_standard': 1000, 'currency_special': 10, 'building': 50}],
    'rehab_center': [{'reception': {'уровень комнаты': 1, # пользователь 1
                                    'пациенты':{
                                            "мальчик Петя": {"состояние": "нуждается в реабилитации", "вид реабилитации": "ЛФК", "настроение": 0}, 
                                            "родитель1": {"настроение": 0}},
                                    'персонажи': {}}, 
                    'office_psych': {'уровень комнаты': 2,
                                     'пациенты':{ 
                                            "девочка Света": {"состояние": "проходит реабилитацию", "вид реабилитации": "массаж", "настроение": 1}, 
                                            "родитель2": {"настроение": 0}},
                                      'персонажи': 'психолог'},    
                    'play_room_1': {'уровень комнаты': 3}}, # комната полностью наполнена мебелью и элементами декора, пациентов в ней нет
                    {'reception': {'уровень комнаты': 1, # пользователь 2
                                   'пациенты':{
                                            "пациент1": {"состояние": "нуждается в реабилитации", "вид реабилитации": "ЛФК", "настроение": 0}, 
                                            "родитель1": {"настроение": 0}},
                                    'персонажи': {'администратор'}
                                    }, 
                    'office_psych': {'уровень комнаты': 2, 
                                     'пациенты':{
                                                "пациент2": {"состояние": "проходит реабилитацию", "вид реабилитации": "массаж", "настроение": 1}, 
                                                "родитель2": {"настроение": 1}},
                                        'персонажи': {'психолог'}}, 
    
                    'play_room_1': {'уровень комнаты': 3,
                                    'пациенты':{}, # пока никого нет
                                    'персонажи':{}},
                    'ward1':{'уровень комнаты': 1},
                                'пациенты':{}, 
                                'персонажи':{}}
   
]}
tab_users = pd.DataFrame(data)
display(tab_users)
# Out:
#              email password  \
# 0  user1@yandex.ru   qwerty
# 1    user2@mail.ru      123
#
#                                             settings  \
# 0  {'volue': 0, 'notifications': 1, 'language': '...
# 1  {'volue': 1, 'notifications': 0, 'language': '...
#
#                                            resources  \
# 0  {'currency_standard': 500, 'currency_special':...
# 1  {'currency_standard': 1000, 'currency_special'...
#
#                                         rehab_center
# 0  {'reception': {'уровень комнаты': 1, 'пациенты...
# 1  {'reception': {'уровень комнаты': 1, 'пациенты...

# %% [markdown]
# Таблица 2:  "Rehab_center" - содержит список локаций и их возможных модификаций. Возможно, она должна быть в БД на стороне Unity.
# Возможные значения:
# 0 - начальное/базовое состояние комнаты
# 1 - в комнату добавлена мебель или тренажер
# 2 - добавлены дополнительные элементы декора
# По сути, для каждой локации существуют 3 готовых варианта. Но, можно рассмотреть возможность добавления в комнату по одному предмету интерьера...

# %%
data = {'rehab_center': [1,2,3], 
    'receptin': [1,2,3], 
    'office_psych': [1,2,3], 
    'physical_therapy_room': [1,2,3],
    'play_room_1': [1,2,3],
    'play_room_2': [1,2,3],
    'play_room_3': [1,2,3],
    'pool': [1,2,3],  
    'room_art': [1,2,3],
    'relax_room': [1,2,3],
    'dining_room': [1,2,3],
    'ward1': [1,2,3],
    'ward2': [1,2,3],
    'ward3': [1,2,3],
    'garden': [1,2,3],
    'pets_room': [1,2,3]}
tab_rehab = pd.DataFrame(data)
display(tab_rehab.T)
# Out:
#                        0  1  2
# rehab_center           1  2  3
# receptin               1  2  3
# office_psych           1  2  3
# physical_therapy_room  1  2  3
# play_room_1            1  2  3
# play_room_2            1  2  3
# play_room_3            1  2  3
# pool                   1  2  3
# room_art               1  2  3
# relax_room             1  2  3
# dining_room            1  2  3
# ward1                  1  2  3
# ward2                  1  2  3
# ward3                  1  2  3
# garden                 1  2  3
# pets_room              1  2  3

# %% [markdown]
# * office_psych - кабинет психолога
# *  physical_therapy_room - кабинет лфк
# * play_room_1 - игровая комната 1
# * play_room_2 - игровая комната 2
# * play_room_3 - игровая комната 3
# * pool - бассейн
# * room_art - комната для занятий творчеством
# * relax_room - комната отдыха
# * dining_room - столовая
# * ward1 - палата на 2 человека 1
# * ward2 - палата на 2 человека 2
# * ward3 - палата на 2 человека 3
# * garden - сад/оранжерея
# * pets_room - уголок с животными

# %% [markdown]
# Таблица3: "Пациенты" - содержит всех возможных пациентов и их родителей. Из этой таблицы берем информацию о пациенте, которую будем показывать/рассказывать игроку.

# %%
data = {'имя': ['мальчик Петя', 'девочка Света'],
        'карточка пациента': ['Пете 7 лет, он родился с ДЦП, он почти не ходит, но всё понимает. Любит рисовать...',
                              'Свете 10 лет, она получила травму головного мозга 3 года назад в результате несчастного случая. Сейчач она не может ходить и у нее нарушена речь...'],
        'диагноз': ['ДЦП', 'Травма головного мозга'],
        'вид реабилитации, в которой нуждается пациент': ['Физиотерапия', 'Массаж']}
tab_patient = pd.DataFrame(data)
display(tab_patient)
# Out:
#              имя                                  карточка пациента  \
# 0   мальчик Петя  Пете 7 лет, он родился с ДЦП, он почти не ходи...
# 1  девочка Света  Свете 10 лет, она получила травму головного мо...
#
#                   диагноз вид реабилитации, в которой нуждается пациент
# 0                     ДЦП                                  Физиотерапия
# 1  Травма головного мозга                                        Массаж

# %% [markdown]
# Таблица4 - "Персонажи" - сотрудники РЦ и доп. персонажи. Здесь же содержатся диалоги (или монологи), которые они будут вести и процедуры, которые они могут проводить с пациентом.
# * Администратор
# * Врач
# * Медсестра
# * Инструктор
# * Психолог
# * Логопед
# * и проч.

# %%
data = {'персонаж': ['администратор', 'врач', 'медсестра', 'инструктор', 'психолог', 'логопед'],
        'монолог': ['Привет', 'Привет', 'Привет', 'Привет', 'Привет', 'Привет'],
        'вид деятельности': ['администрирование', 'назначение процедур','проведение процедур', 'ЛФК', 'психотерапия', 'развитие речи']}
tab_persone = pd.DataFrame(data)
display(tab_persone)
# Out:
#         персонаж монолог     вид деятельности
# 0  администратор  Привет    администрирование
# 1           врач  Привет  назначение процедур
# 2      медсестра  Привет  проведение процедур
# 3     инструктор  Привет                  ЛФК
# 4       психолог  Привет         психотерапия
# 5        логопед  Привет        развитие речи

# %% [markdown]
# Таблица5 - "Процедуры". Скорее всего, её не нужно создавать.
# * физиотерапия
# * арт-терапия
# * массажные процедуры
# * занятия на тренажере беговая дорожка
# * занятие на тренажере для растяжки
# * занятие на тренажере брусья-лестница
# * занятие в бассейне
# * занятие с животными
# * занятие с реабилитологом

# %% [markdown]
# Таблица6 - "Задачи", - пока не вижу смысла её создавать, т.к. задачи должны быть прописаны в сценарии...
